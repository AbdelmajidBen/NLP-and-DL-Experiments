# %%
import pandas as pd

# %%
df1 = pd.read_csv('d1.csv')
df2 = pd.read_csv('d2.csv')

# %%
dataset = pd.concat([df1, df2], axis=0)

# %%
dataset
# Out:
#                                             text;score
# 0    الذكاء الاصطناعي (AI) هو مجال علوم الكمبيوتر ا...
# 1    المعرفية المرتبطة عادةً بالذكاء البشري، مثل ال...
# 2    الصور. تجمع المؤسسات الحديثة كمياتٍ كبيرةً من ...
# 3    متنوعة مثل أجهزة الاستشعار الذكية والمحتوى الذ...
# 4    المراقبة وسجلات النظام. الهدف من الذكاء الاصطن...
# ..                                                 ...
# 255          الاصطناعي التي تتضمن تطوير الاستراتيجية;9
# 256                      والوصول إلى الأدوات ابحث عن;5
# 257                       شريك لديه الخبرة في المجال;2
# 258               ومجموعة شاملة من الذكاء الاصطناعي;10
# 259                     مكتبة تعلم الذكاء الاصطناعي;10
#
# [496 rows x 1 columns]

# %%
dataset[['text', 'score']] = dataset['text;score'].str.split(';', expand=True)

dataset.drop(columns=['text;score'], inplace=True)

# %%
def ponctuation(phrase):
    phrase2=" "
    arabic_punctuations = '''`.‏،÷×؛<>_()*&^%][ـ،/:"؟.,'{}~¦+|!”…“–ـ'''
    english_punctuations = string.punctuation
    punctuations_list = arabic_punctuations + english_punctuations
    newPhrase=phrase.translate(str.maketrans(punctuations_list, ' '*len(punctuations_list)))
    newPhrase=re.sub('[0-9]',' ',phrase)
    newPhrase=re.sub('[\n,\t,\r,\n\n,\u200f]',' ',newPhrase)
    liste=newPhrase.split()
    return phrase2.join(liste)

# %%
def ponc_noarabic(text):
    p=" "
    COMMA            = u'\u060C'
    SEMICOLON        = u'\u061B'
    QUESTION         = u'\u061F'
    HAMZA            = u'\u0621'
    ALEF_MADDA       = u'\u0622'
    ALEF_HAMZA_ABOVE = u'\u0623'
    list1=tokenize(text, conditions=is_arabicrange, morphs=strip_tashkeel)
    unwanted_num = {COMMA,SEMICOLON,QUESTION,HAMZA,ALEF_MADDA,ALEF_HAMZA_ABOVE}
    list1 = [ele for ele in list1 if ele not in unwanted_num]
    return p.join(list1)

# %%
def clean_data(phrase):
    phrase2= " ";a=[]
    newPhrase=phrase.translate(str.maketrans(string.punctuation, ' '*len(string.punctuation)))
    newPhrase=re.sub('[0-9]',' ',newPhrase)
    liste=newPhrase.split()
    stops = set(stopwords.words('arabic'))
    stops={i.translate(str.maketrans("'"," ",string.punctuation)) for i in stops}
    p=["لكن","لا","لم"]
    stop=stops.difference(p)
    for i in liste:
        if i not in stop and i not in a:
            a.append(i)
    return phrase2.join(a)

# %%
def arabic_clean(text):
    text=ponctuation(text)
    text=ponc_noarabic(text)
    text=clean_data(text)
    return text

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import csv
import nltk
from pyarabic.araby import tokenize, is_arabicrange, strip_tashkeel
import string
from nltk.corpus import stopwords
import re

dataset['T1'] =dataset['text'].apply(lambda x: arabic_clean(x))

# %%
dataset
# Out:
#                                                   text score  \
# 0    الذكاء الاصطناعي (AI) هو مجال علوم الكمبيوتر ا...    10
# 1    المعرفية المرتبطة عادةً بالذكاء البشري، مثل ال...     8
# 2    الصور. تجمع المؤسسات الحديثة كمياتٍ كبيرةً من ...     2
# 3    متنوعة مثل أجهزة الاستشعار الذكية والمحتوى الذ...     7
# 4    المراقبة وسجلات النظام. الهدف من الذكاء الاصطن...     9
# ..                                                 ...   ...
# 255            الاصطناعي التي تتضمن تطوير الاستراتيجية     9
# 256                        والوصول إلى الأدوات ابحث عن     5
# 257                         شريك لديه الخبرة في المجال     2
# 258                  ومجموعة شاملة من الذكاء الاصطناعي    10
# 259                        مكتبة تعلم الذكاء الاصطناعي    10
#
#                                                     T1
# 0    الذكاء الاصطناعي مجال علوم الكمبيوتر المخصص لح...
# 1    المعرفية المرتبطة عادة بالذكاء البشري التعلم و...
# 2    الصور تجمع المؤسسات الحديثة كميات كبيرة البيان...
# 3    متنوعة أجهزة الاستشعار الذكية والمحتوى ينشئه ا...
# 4    المراقبة وسجلات النظام الهدف الذكاء الاصطناعي ...
# ..                                                 ...
# 255                 الاصطناعي تتضمن تطوير الاستراتيجية
# 256                               والوصول الأدوات ابحث
# 257                            شريك لديه الخبرة المجال
# 258                     ومجموعة شاملة الذكاء الاصطناعي
# 259                        مكتبة تعلم الذكاء الاصطناعي
#
# [496 rows x 3 columns]

# %%
import tensorflow as tf

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, GRU, Bidirectional, Dense

# %%
texts = dataset['T1'].tolist()
scores = dataset['score'].tolist()

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
scores=lb.fit_transform(scores)

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(texts)
vocab_size = len(tokenizer.word_index) + 1
sequences = tokenizer.texts_to_sequences(texts)

# %%
max_length = max(len(seq) for seq in sequences)
padded_sequences = pad_sequences(sequences, maxlen=max_length, padding='post')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(padded_sequences, scores, test_size=0.2, random_state=42)

# %%
def create_model(architecture):
    model = Sequential()
    model.add(Embedding(vocab_size, 100, input_length=max_length))
    if architecture == 'RNN':
        model.add(LSTM(64, dropout=0.2))
    elif architecture == 'Bidirectional_RNN':
        model.add(Bidirectional(LSTM(64, dropout=0.2)))
    elif architecture == 'GRU':
        model.add(GRU(64, dropout=0.2))
    elif architecture == 'LSTM':
        model.add(LSTM(64, dropout=0.2))
    model.add(Dense(1, activation='linear'))
    return model

# %%
architectures = ['RNN', 'Bidirectional_RNN', 'GRU', 'LSTM']
for architecture in architectures:
    model = create_model(architecture)
    model.compile(optimizer='adam', loss='mse', metrics=['mae'])
    print(f"Training {architecture} model...")
    model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), verbose=1)
    loss, mae = model.evaluate(X_test, y_test, verbose=0)
    print(f"{architecture} model - Test Loss: {loss}, Test MAE: {mae}")
# Out:
# Training RNN model...
# Epoch 1/50
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 51.8471 - mae: 6.4133 - val_loss: 27.9014 - val_mae: 4.1338
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 27.4909 - mae: 4.3521 - val_loss: 15.5358 - val_mae: 3.5238
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12.0726 - mae: 3.1044 - val_loss: 13.8273 - val_mae: 3.4022
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.1126 - mae: 2.8413 - val_loss: 12.2108 - val_mae: 3.2033
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.1118 - mae: 2.8898 - val_loss: 12.7660 - val_mae: 3.2748
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.2886 - mae: 2.9283 - val_loss: 12.9886 - val_mae: 3.2939
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.5997 - mae: 2.8134 - val_loss: 12.5458 - val_mae: 3.2339
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.0078 - mae: 2.8703 - val_loss: 12.5009 - val_mae: 3.2192
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.4361 - mae: 2.7700 - val_loss: 13.0247 - val_mae: 3.2657
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.7152 - mae: 2.7902 - val_loss: 12.6916 - val_mae: 3.2193
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.1459 - mae: 2.7022 - val_loss: 12.9437 - val_mae: 3.2421
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.8424 - mae: 2.6369 - val_loss: 13.4831 - val_mae: 3.2780
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.7507 - mae: 2.5831 - val_loss: 13.3152 - val_mae: 3.2468
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.4127 - mae: 2.7278 - val_loss: 13.5447 - val_mae: 3.2728
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.3515 - mae: 2.4900 - val_loss: 13.3168 - val_mae: 3.2387
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.5785 - mae: 2.5394 - val_loss: 13.9555 - val_mae: 3.2808
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.7400 - mae: 2.3590 - val_loss: 13.6021 - val_mae: 3.2067
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.6935 - mae: 2.1436 - val_loss: 13.6591 - val_mae: 3.1615
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.4582 - mae: 1.6072 - val_loss: 12.9181 - val_mae: 3.0375
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.2407 - mae: 1.5434 - val_loss: 14.6035 - val_mae: 3.1284
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.9902 - mae: 1.2901 - val_loss: 11.4143 - val_mae: 2.7194
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1118 - mae: 1.0988 - val_loss: 15.2905 - val_mae: 3.1083
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0254 - mae: 1.0048 - val_loss: 11.4431 - val_mae: 2.6958
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9770 - mae: 0.9621 - val_loss: 11.9893 - val_mae: 2.7305
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3326 - mae: 0.8567 - val_loss: 11.5863 - val_mae: 2.6656
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3244 - mae: 0.8167 - val_loss: 11.6247 - val_mae: 2.6875
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0106 - mae: 0.7504 - val_loss: 12.2003 - val_mae: 2.7360
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8610 - mae: 0.6827 - val_loss: 10.8591 - val_mae: 2.5708
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9575 - mae: 0.6993 - val_loss: 10.7719 - val_mae: 2.5525
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8509 - mae: 0.6383 - val_loss: 11.0205 - val_mae: 2.5891
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9883 - mae: 0.6493 - val_loss: 10.8674 - val_mae: 2.5723
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6071 - mae: 0.5667 - val_loss: 10.7557 - val_mae: 2.5320
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5388 - mae: 0.5660 - val_loss: 10.9281 - val_mae: 2.5522
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4289 - mae: 0.5066 - val_loss: 10.6184 - val_mae: 2.5040
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5157 - mae: 0.5415 - val_loss: 11.0199 - val_mae: 2.5720
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4975 - mae: 0.5252 - val_loss: 11.4189 - val_mae: 2.6083
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4138 - mae: 0.4864 - val_loss: 10.8051 - val_mae: 2.5512
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4244 - mae: 0.4839 - val_loss: 10.4994 - val_mae: 2.5076
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4772 - mae: 0.4971 - val_loss: 11.0835 - val_mae: 2.5718
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3298 - mae: 0.4248 - val_loss: 11.0193 - val_mae: 2.5613
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3647 - mae: 0.4573 - val_loss: 10.4217 - val_mae: 2.5087
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3462 - mae: 0.4333 - val_loss: 10.4246 - val_mae: 2.4922
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2881 - mae: 0.4016 - val_loss: 10.8053 - val_mae: 2.5248
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2999 - mae: 0.3910 - val_loss: 10.8356 - val_mae: 2.5321
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3040 - mae: 0.3955 - val_loss: 10.9406 - val_mae: 2.5380
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2171 - mae: 0.3325 - val_loss: 10.6790 - val_mae: 2.5176
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2560 - mae: 0.3598 - val_loss: 10.8962 - val_mae: 2.5361
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2909 - mae: 0.3674 - val_loss: 10.7785 - val_mae: 2.4997
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2044 - mae: 0.3352 - val_loss: 10.9538 - val_mae: 2.5443
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2238 - mae: 0.3316 - val_loss: 11.1489 - val_mae: 2.5651
# RNN model - Test Loss: 11.148857116699219, Test MAE: 2.5651051998138428
# Training Bidirectional_RNN model...
# Epoch 1/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 50.4048 - mae: 6.2892 - val_loss: 25.2857 - val_mae: 3.9364
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 21.0671 - mae: 3.8235 - val_loss: 17.6630 - val_mae: 3.7871
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 12.5098 - mae: 3.1645 - val_loss: 12.3140 - val_mae: 3.2053
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 10.5508 - mae: 2.9582 - val_loss: 12.5112 - val_mae: 3.2474
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 10.5276 - mae: 2.9640 - val_loss: 12.7910 - val_mae: 3.2728
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.9497 - mae: 2.8712 - val_loss: 12.2243 - val_mae: 3.2020
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.7779 - mae: 2.8330 - val_loss: 12.0086 - val_mae: 3.1610
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.8929 - mae: 2.6831 - val_loss: 11.9550 - val_mae: 3.1238
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.6736 - mae: 2.4417 - val_loss: 11.7205 - val_mae: 3.0637
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.8571 - mae: 2.4571 - val_loss: 12.0773 - val_mae: 3.0588
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.1072 - mae: 2.2435 - val_loss: 11.3096 - val_mae: 2.8835
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.6025 - mae: 1.9356 - val_loss: 11.4768 - val_mae: 2.8745
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.6817 - mae: 1.6916 - val_loss: 10.9605 - val_mae: 2.7656
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.1221 - mae: 1.5833 - val_loss: 11.4909 - val_mae: 2.8033
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.6265 - mae: 1.4702 - val_loss: 11.3904 - val_mae: 2.7791
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.6785 - mae: 1.2309 - val_loss: 12.4369 - val_mae: 2.9166
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.2268 - mae: 1.0817 - val_loss: 10.1284 - val_mae: 2.6078
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.8362 - mae: 0.9601 - val_loss: 10.3385 - val_mae: 2.6402
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4426 - mae: 0.8560 - val_loss: 11.1224 - val_mae: 2.7646
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0144 - mae: 0.6984 - val_loss: 10.3461 - val_mae: 2.6379
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9346 - mae: 0.6675 - val_loss: 9.9881 - val_mae: 2.5696
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.6946 - mae: 0.6061 - val_loss: 10.6430 - val_mae: 2.6822
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.6954 - mae: 0.5920 - val_loss: 10.7691 - val_mae: 2.6741
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4166 - mae: 0.4774 - val_loss: 10.4603 - val_mae: 2.6212
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4098 - mae: 0.4688 - val_loss: 10.4027 - val_mae: 2.5977
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3202 - mae: 0.4058 - val_loss: 10.4193 - val_mae: 2.5964
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2841 - mae: 0.3906 - val_loss: 10.7629 - val_mae: 2.6401
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2479 - mae: 0.3746 - val_loss: 10.7160 - val_mae: 2.6314
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2940 - mae: 0.3946 - val_loss: 10.5246 - val_mae: 2.5861
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2539 - mae: 0.3737 - val_loss: 10.3531 - val_mae: 2.5695
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2688 - mae: 0.3827 - val_loss: 10.3935 - val_mae: 2.5643
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1996 - mae: 0.3402 - val_loss: 10.3017 - val_mae: 2.5462
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1881 - mae: 0.3163 - val_loss: 10.3300 - val_mae: 2.5409
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2030 - mae: 0.3273 - val_loss: 10.3107 - val_mae: 2.5366
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1975 - mae: 0.3386 - val_loss: 10.3532 - val_mae: 2.5520
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1436 - mae: 0.2817 - val_loss: 10.2907 - val_mae: 2.5399
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1708 - mae: 0.3232 - val_loss: 10.4650 - val_mae: 2.5650
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1615 - mae: 0.2947 - val_loss: 10.6659 - val_mae: 2.5853
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1603 - mae: 0.2930 - val_loss: 10.3321 - val_mae: 2.5359
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1204 - mae: 0.2631 - val_loss: 10.3450 - val_mae: 2.5208
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1221 - mae: 0.2652 - val_loss: 10.2366 - val_mae: 2.5340
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1176 - mae: 0.2494 - val_loss: 10.4700 - val_mae: 2.5575
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0918 - mae: 0.2280 - val_loss: 10.1653 - val_mae: 2.4982
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0833 - mae: 0.2227 - val_loss: 10.2151 - val_mae: 2.5142
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0953 - mae: 0.2271 - val_loss: 10.2763 - val_mae: 2.5252
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1116 - mae: 0.2369 - val_loss: 10.5120 - val_mae: 2.5546
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0959 - mae: 0.2225 - val_loss: 10.3146 - val_mae: 2.5200
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0894 - mae: 0.2282 - val_loss: 10.1764 - val_mae: 2.4971
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0828 - mae: 0.2146 - val_loss: 10.2400 - val_mae: 2.5042
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0723 - mae: 0.2017 - val_loss: 10.4275 - val_mae: 2.5435
# Bidirectional_RNN model - Test Loss: 10.427456855773926, Test MAE: 2.543545722961426
# Training GRU model...
# Epoch 1/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 52.2253 - mae: 6.4341 - val_loss: 25.3360 - val_mae: 3.8673
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 26.6904 - mae: 4.3425 - val_loss: 19.8913 - val_mae: 3.9899
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.3407 - mae: 3.4173 - val_loss: 15.8095 - val_mae: 3.6185
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 12.6591 - mae: 3.1891 - val_loss: 13.7061 - val_mae: 3.3499
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.5986 - mae: 3.0564 - val_loss: 14.0972 - val_mae: 3.4379
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.0668 - mae: 3.0155 - val_loss: 13.5241 - val_mae: 3.3705
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.6487 - mae: 2.9641 - val_loss: 12.6639 - val_mae: 3.2676
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.3725 - mae: 2.9335 - val_loss: 12.8352 - val_mae: 3.2867
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.1209 - mae: 2.8858 - val_loss: 12.7472 - val_mae: 3.2750
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.5991 - mae: 2.7808 - val_loss: 12.5596 - val_mae: 3.2505
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.0726 - mae: 2.8571 - val_loss: 12.5960 - val_mae: 3.2471
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.9269 - mae: 2.6835 - val_loss: 12.5074 - val_mae: 3.2232
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.9171 - mae: 2.6786 - val_loss: 12.3071 - val_mae: 3.1743
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.1326 - mae: 2.4817 - val_loss: 12.5559 - val_mae: 3.1385
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.9482 - mae: 2.4368 - val_loss: 12.4263 - val_mae: 3.0674
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.7939 - mae: 1.9820 - val_loss: 12.4486 - val_mae: 2.9733
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.2438 - mae: 1.5800 - val_loss: 12.3013 - val_mae: 2.8465
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6597 - mae: 1.2664 - val_loss: 12.1877 - val_mae: 2.7691
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0227 - mae: 1.0258 - val_loss: 11.2924 - val_mae: 2.6237
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6770 - mae: 1.0013 - val_loss: 11.6259 - val_mae: 2.6625
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4464 - mae: 0.8620 - val_loss: 10.4520 - val_mae: 2.5006
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4443 - mae: 0.7848 - val_loss: 11.2482 - val_mae: 2.6099
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.2969 - mae: 0.8157 - val_loss: 11.4458 - val_mae: 2.6337
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8246 - mae: 0.6734 - val_loss: 10.7779 - val_mae: 2.5490
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9076 - mae: 0.6661 - val_loss: 10.8329 - val_mae: 2.5566
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6681 - mae: 0.6059 - val_loss: 10.2819 - val_mae: 2.4786
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6447 - mae: 0.5628 - val_loss: 10.7478 - val_mae: 2.5542
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7020 - mae: 0.5864 - val_loss: 11.1298 - val_mae: 2.5951
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4757 - mae: 0.5105 - val_loss: 10.3745 - val_mae: 2.4900
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4554 - mae: 0.4993 - val_loss: 10.4748 - val_mae: 2.4933
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4423 - mae: 0.4936 - val_loss: 10.8866 - val_mae: 2.5552
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2999 - mae: 0.4336 - val_loss: 10.8771 - val_mae: 2.5833
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2947 - mae: 0.4079 - val_loss: 10.9751 - val_mae: 2.5750
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2457 - mae: 0.3792 - val_loss: 10.7090 - val_mae: 2.5436
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2632 - mae: 0.3983 - val_loss: 10.4912 - val_mae: 2.4994
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2353 - mae: 0.3650 - val_loss: 10.7099 - val_mae: 2.5549
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2190 - mae: 0.3516 - val_loss: 10.6275 - val_mae: 2.5492
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2132 - mae: 0.3573 - val_loss: 10.5861 - val_mae: 2.5311
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2016 - mae: 0.3487 - val_loss: 10.4766 - val_mae: 2.5359
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1930 - mae: 0.3318 - val_loss: 10.6321 - val_mae: 2.5351
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1788 - mae: 0.3118 - val_loss: 10.4450 - val_mae: 2.5352
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1870 - mae: 0.3021 - val_loss: 10.5973 - val_mae: 2.5238
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1504 - mae: 0.2891 - val_loss: 10.4641 - val_mae: 2.5281
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1523 - mae: 0.2759 - val_loss: 10.4407 - val_mae: 2.5183
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1557 - mae: 0.3004 - val_loss: 10.3031 - val_mae: 2.4876
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1679 - mae: 0.3023 - val_loss: 10.2978 - val_mae: 2.5055
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1458 - mae: 0.2914 - val_loss: 10.3656 - val_mae: 2.5017
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1228 - mae: 0.2546 - val_loss: 10.4199 - val_mae: 2.5124
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1136 - mae: 0.2488 - val_loss: 10.3485 - val_mae: 2.4845
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1164 - mae: 0.2523 - val_loss: 10.2551 - val_mae: 2.4894
# GRU model - Test Loss: 10.2550630569458, Test MAE: 2.4893970489501953
# Training LSTM model...
# Epoch 1/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 51.5016 - mae: 6.3861 - val_loss: 26.4975 - val_mae: 3.9827
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 25.0981 - mae: 4.0211 - val_loss: 17.1701 - val_mae: 3.7150
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12.9520 - mae: 3.1912 - val_loss: 13.0848 - val_mae: 3.3112
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.4521 - mae: 2.9309 - val_loss: 12.4257 - val_mae: 3.2371
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.6944 - mae: 2.8121 - val_loss: 12.6118 - val_mae: 3.2598
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.8173 - mae: 2.8012 - val_loss: 12.7853 - val_mae: 3.2754
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.1083 - mae: 2.7333 - val_loss: 12.9649 - val_mae: 3.2902
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.8934 - mae: 2.8438 - val_loss: 12.4850 - val_mae: 3.2273
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.8905 - mae: 2.8289 - val_loss: 12.6326 - val_mae: 3.2328
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.6805 - mae: 2.8052 - val_loss: 13.0947 - val_mae: 3.2773
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.8031 - mae: 2.7737 - val_loss: 12.8966 - val_mae: 3.2341
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.2127 - mae: 2.6895 - val_loss: 13.1021 - val_mae: 3.2466
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.6453 - mae: 2.5922 - val_loss: 13.1945 - val_mae: 3.2412
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.6976 - mae: 2.5875 - val_loss: 13.1329 - val_mae: 3.2265
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.4427 - mae: 2.5766 - val_loss: 13.2083 - val_mae: 3.2319
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.0291 - mae: 2.4822 - val_loss: 13.3579 - val_mae: 3.2307
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.4588 - mae: 2.3496 - val_loss: 13.5747 - val_mae: 3.2311
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.5429 - mae: 2.1414 - val_loss: 12.9229 - val_mae: 3.1419
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.3372 - mae: 1.8883 - val_loss: 13.3277 - val_mae: 3.1319
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.7918 - mae: 1.5052 - val_loss: 13.8759 - val_mae: 3.1403
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.1287 - mae: 1.3267 - val_loss: 12.7616 - val_mae: 2.9097
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.8481 - mae: 1.2872 - val_loss: 16.4884 - val_mae: 3.2533
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6873 - mae: 1.1457 - val_loss: 11.5500 - val_mae: 2.7308
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8651 - mae: 0.9955 - val_loss: 13.1913 - val_mae: 2.8895
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4060 - mae: 0.8833 - val_loss: 13.1870 - val_mae: 2.8946
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1850 - mae: 0.7850 - val_loss: 12.1165 - val_mae: 2.7576
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9693 - mae: 0.7421 - val_loss: 12.7094 - val_mae: 2.8072
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9604 - mae: 0.7060 - val_loss: 12.1498 - val_mae: 2.7396
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7793 - mae: 0.6680 - val_loss: 10.9769 - val_mae: 2.5961
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7183 - mae: 0.6405 - val_loss: 12.0059 - val_mae: 2.6996
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6407 - mae: 0.6008 - val_loss: 12.1734 - val_mae: 2.7238
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5639 - mae: 0.5561 - val_loss: 10.7136 - val_mae: 2.5770
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6171 - mae: 0.5902 - val_loss: 11.7823 - val_mae: 2.6580
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4879 - mae: 0.5291 - val_loss: 11.8261 - val_mae: 2.6657
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4189 - mae: 0.4918 - val_loss: 11.5349 - val_mae: 2.6461
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4139 - mae: 0.4799 - val_loss: 11.4723 - val_mae: 2.6287
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3649 - mae: 0.4559 - val_loss: 10.7453 - val_mae: 2.5366
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3715 - mae: 0.4465 - val_loss: 10.9865 - val_mae: 2.5731
# Epoch 39/50
#  1/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3667 - mae: 0.4234
